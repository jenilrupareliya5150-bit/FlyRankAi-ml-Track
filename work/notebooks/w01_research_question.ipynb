# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jenilrupareliya5150-bit/FlyRankAi-ml-Track/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane Refresh Opportunity Scoring
# I selected the **Refresh Opportunity Scoring** lane because websites often contain hundreds or thousands of webpages, but SEO teams have limited time to update them. Instead of manually reviewing every page, I want to build a data-driven approach that identifies which pages are the best candidates for a content refresh.
#
# This lane interests me because it combines feature engineering, machine learning, and business decision-making. By analyzing historical Google Search performance signals such as impressions, clicks, ranking position, and content age, I aim to help prioritize pages that are most likely to benefit from being refreshed. This can improve SEO efficiency while reducing manual effort.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# #2. Research Question
#
# ## Decision
#
# Which webpages should be refreshed first to maximize future search traffic?
#
# ## Action
#
# SEO or content managers can update the selected pages by improving outdated content, adding missing information, optimizing keywords, and improving page quality.
#
# ## Cost of a Wrong Recommendation
#
# If pages that do not actually need updating are selected, time and resources are wasted. More importantly, pages that truly need a refresh may continue losing search traffic, reducing website visibility and business opportunities.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
#
#
# The starter dataset contains **30,000 content pages** from **32 different clients**, making it suitable for analyzing refresh opportunities across multiple websites instead of a single project.
#
# The average monthly search volume is approximately **159**, but the distribution is highly skewed. While many pages have little or no search demand, some keywords reach **74,000** searches, indicating that refresh priorities should consider both opportunity and potential impact.
#
# Most of the dataset consists of **keyword articles (27,207 pages)**, and the dominant search intent is **informational (17,235 pages)**. This suggests that improving informational content could have a meaningful impact on overall organic search performance.

# %%
# !git clone https://github.com/jenilrupareliya5150-bit/FlyRankAi-ml-Track.git
# Out:
# Cloning into 'FlyRankAi-ml-Track'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 139 (delta 51), reused 90 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (139/139), 1.86 MiB | 6.08 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# %cd FlyRankAi-ml-Track
# Out:
# /content/FlyRankAi-ml-Track

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

df.sample(5)
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#                  content_id          client_id  search_volume  competition  \
# 29707  content_1794af0c40fd  client_6208ef0f77            0.0         0.00
# ...

# %%
print(df[['search_volume','competition','cpc']].describe())

print("\nUnique Clients:", df['client_id'].nunique())
print("Unique Content Pages:", df['content_id'].nunique())
# Out:
#        search_volume   competition           cpc
# count   27532.000000  27532.000000  27532.000000
# mean      158.882391      0.146954      0.485342
# std      1518.270825      0.285241      2.101560
# min         0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000
# 50%        10.000000      0.000000      0.000000
# 75%        20.000000      0.130000      0.000000
# max     74000.000000      1.000000    100.360000
#
# Unique Clients: 32
# Unique Content Pages: 30000

# %%
print(df['content_type'].value_counts())
# Out:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %%
print(df['main_intent'].value_counts())
# Out:
# main_intent
# informational    17235
# transactional     5733
# commercial        4612
# navigational        46
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
#
#
# ### What I can claim
#
# This project analyzes historical SEO data to identify webpages that may be strong candidates for a content refresh. By using observable features such as search volume, competition, content type, search intent, and other available metrics, it provides **decision support** for SEO and content teams when deciding which pages to review first.
#
# The results indicate patterns and relationships in the data that can help prioritize refresh efforts, making the decision process more data-driven.
#
# ### What I can't claim
#
# This project **cannot prove** that refreshing a webpage will increase its Google rankings, clicks, or traffic. Search performance is influenced by many external factors, including Google's ranking algorithms, competitors, seasonality, user behavior, and website authority.
#
# Therefore, this work should be treated as a **decision-support tool**, not as a system that predicts Google's rankings or guarantees SEO improvements.

# %%
Sdf = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)

print("\nUnique Clients:", df["client_id"].nunique())
print("Unique Content Pages:", df["content_id"].nunique())

print("\nSearch Volume Statistics")
print(df["search_volume"].describe())

print("\nContent Types")
print(df["content_type"].value_counts())

print("\nMain Intent")
print(df["main_intent"].value_counts())
# Out:
# Dataset Shape: (30000, 44)
#
# Unique Clients: 32
# Unique Content Pages: 30000
#
# Search Volume Statistics
# count    27532.000000
# mean       158.882391
# std       1518.270825
# min          0.000000
# 25%          0.000000
# 50%         10.000000
# 75%         20.000000
# max      74000.000000
# Name: search_volume, dtype: float64
#
# Content Types
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Main Intent
# main_intent
# informational    17235
# transactional     5733
# commercial        4612
# navigational        46
# Name: count, dtype: int64

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
